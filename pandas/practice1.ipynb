# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "name":['aryan','bryan','cryan'],
    "marks":[100,99,98],
    "city":['jodhpur','jalandhar','bihar']
}

# %%
df = pd.DataFrame(dict1)

# %%
df.head(2)
# Out:
#     name  marks       city
# 1  bryan     99  jalandhar
# 2  cryan     98      bihar

# %%
df.tail(2)
# Out:
#     name  marks       city
# 1  bryan     99  jalandhar
# 2  cryan     98      bihar

# %%
df.describe()
# Out:
#        marks
# count    3.0
# mean    99.0
# std      1.0
# min     98.0
# 25%     98.5
# 50%     99.0
# 75%     99.5
# max    100.0

# %%
datasheet1 = pd.read_csv('Admission_Predict.csv')

# %%
datasheet1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
resultSheet = datasheet1.sort_values(by = 'TOEFL Score',ascending = False)

# %%
resultSheet.head(5)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 25           26        340          120                  5  4.5   4.5  9.60
# 97           98        331          120                  3  4.0   4.0  8.96
# 81           82        340          120                  4  5.0   5.0  9.50
# 202         203        340          120                  5  4.5   4.5  9.91
# 203         204        334          120                  5  4.0   5.0  9.87
#
#      Research  Chance of Admit
# 25          1              0.94
# 97          1              0.86
# 81          1              0.96
# 202         1              0.97
# 203         1              0.97
